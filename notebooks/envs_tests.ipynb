# %% [markdown]
# # Constant policy simulations

# %%
import random

from loguru import logger
from pandemic_control.utils import (
    Args,
    set_plot_env,
    run_const_policy_simulations,
)

# %%
args = Args(
    const_policy_simulations=True,
    model_policy_simulations= False,
    plot_heatmaps=False,
    plot_learning_curves=False,
    preprocess_data=False,
    train=False,
    predict=False,

    env_type='SEIRADHV',
    cfg_file='./configs/envs_tests/default-seiradhv.json',
    model_type=None,
    model_weights=None,

    input_dir=None,
    output_dir='./outputs',

    seed=random.choice([33, 45, 75, 99]),
    t_max=366,
    timesteps=366,
    days_per_restrict=7,
    epochs=50,
    rounds=50,
    save_interval=10,
    show_plot=True
    )

cfg_filepaths = {
    'SIR': './configs/envs_tests/default-seird.json',
    'SEIR': './configs/envs_tests/default-seird.json',
    'SEIRD': './configs/envs_tests/default-seird.json',
    'SEIRAD': './configs/envs_tests/default-seirad.json',
    'SEIRADH': './configs/envs_tests/default-seiradhv.json',
    'SEIRADHV': './configs/envs_tests/default-seiradhv.json',
}
set_plot_env()

logger.info(f"### Running constant policy simulations.")

for env_name, cfg_file in cfg_filepaths.items():
    args.env_type = env_name
    args.cfg_file = cfg_file
    run_const_policy_simulations(args)

logger.info(f"### Simulations complete.")

# %% [markdown]
# # Agent-controlled simulations

# %%
import random
import pandas as pd
from loguru import logger

from pandemic_control.utils import (
    Args,
    set_plot_env,
    run_model_policy_simulations,
    RewardCallback,
)

# %%
args = Args(
    const_policy_simulations=False,
    model_policy_simulations= True,
    plot_heatmaps=False,
    plot_learning_curves=False,
    preprocess_data=False,
    train=False,
    predict=False,

    env_type='SEIRADHV',
    cfg_file='./configs/envs_tests/default-seiradhv.json',
    model_type='PPO',
    model_weights=None,

    input_dir=None,
    output_dir='./outputs',

    seed=random.choice([33, 45, 75, 99]),
    t_max=365,
    timesteps=728,
    epochs=50,
    rounds=50,
    save_interval=10,
    show_plot=True
    )


cfg_filepaths = {
    'SIR': './configs/envs_tests/default-seird.json',
    'SEIR': './configs/envs_tests/default-seird.json',
    'SEIRD': './configs/envs_tests/default-seird.json',
    'SEIRAD': './configs/envs_tests/default-seirad.json',
    'SEIRADH': './configs/envs_tests/default-seiradhv.json',
    'SEIRADHV': './configs/envs_tests/default-seiradhv.json',
}


# For plotting
set_plot_env()


logger.info(f"### Running agent-controlled simulations.")
for env_name, cfg_file in cfg_filepaths.items():
    if env_name!='SEIRADHV': # TODO: Remove this line after debugging
        continue
    args.env_name = env_name
    args.cfg_file = cfg_file

    # For debug
    args.epochs = 20
    args.save_interval = args.epochs//10 if args.epochs >= 10 else None
    args.rounds = 20

    cb = RewardCallback()
    run_model_policy_simulations(args, cb)
    print(len(cb.episode_rewards), len(cb.step_rewards))
# Out:
# 2026-08-05 21:45:06.519 | INFO     | __main__:<module>:42 - ### Running agent-controlled simulations.
# 2026-08-05 21:45:06.521 | INFO     | pandemic_control.utils.runners:run_model_policy_simulations:63 - *** Loading 'SEIRADHV' environment.
# 2026-08-05 21:45:06.522 | INFO     | pandemic_control.utils.runners:run_model_policy_simulations:69 - *** Loading 'PPO' agent.
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# 2026-08-05 21:45:07.210 | INFO     | pandemic_control.utils.runners:run_model_policy_simulations:84 - *** Starting training.
# Logging to ./outputs/basic_tests/seiradhv_ppo/logs/seiradhv_history_35
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Logging to ./outputs/basic_tests/seiradhv_ppo/logs/seiradhv_history_36
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Logging to ./outputs/basic_tests/seiradhv_ppo/logs/seiradhv_history_37
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Logging to ./outputs/basic_tests/seiradhv_ppo/logs/seiradhv_history_38
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Logging to ./outputs/basic_tests/seiradhv_ppo/logs/seiradhv_history_39
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Logging to ./outputs/basic_tests/seiradhv_ppo/logs/seiradhv_history_40
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Logging to ./outputs/basic_tests/seiradhv_ppo/logs/seiradhv_history_41
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Logging to ./outputs/basic_tests/seiradhv_ppo/logs/seiradhv_history_42
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Logging to ./outputs/basic_tests/seiradhv_ppo/logs/seiradhv_history_43
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Logging to ./outputs/basic_tests/seiradhv_ppo/logs/seiradhv_history_44
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Logging to ./outputs/basic_tests/seiradhv_ppo/logs/seiradhv_history_45
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Logging to ./outputs/basic_tests/seiradhv_ppo/logs/seiradhv_history_46
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Logging to ./outputs/basic_tests/seiradhv_ppo/logs/seiradhv_history_47
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Logging to ./outputs/basic_tests/seiradhv_ppo/logs/seiradhv_history_48
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Logging to ./outputs/basic_tests/seiradhv_ppo/logs/seiradhv_history_49
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Logging to ./outputs/basic_tests/seiradhv_ppo/logs/seiradhv_history_50
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Logging to ./outputs/basic_tests/seiradhv_ppo/logs/seiradhv_history_51
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Logging to ./outputs/basic_tests/seiradhv_ppo/logs/seiradhv_history_52
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Logging to ./outputs/basic_tests/seiradhv_ppo/logs/seiradhv_history_53
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Logging to ./outputs/basic_tests/seiradhv_ppo/logs/seiradhv_history_54
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 2026-08-05 21:46:44.691 | INFO     | pandemic_control.utils.runners:run_model_policy_simulations:93 - *** Training done. Plotting rewards curves.
# 2026-08-05 21:46:45.535 | INFO     | pandemic_control.utils.runners:run_model_policy_simulations:126 - *** Loading model from disk.
# 2026-08-05 21:46:45.655 | INFO     | pandemic_control.utils.runners:run_model_policy_simulations:135 - *** Running one simulation.
# 2026-08-05 21:46:45.658 | INFO     | pandemic_control.utils.runners:run_model_policy_simulations:137 - *** Plotting curves based on one years' data
# 2026-08-05 21:46:48.421 | INFO     | pandemic_control.utils.runners:run_model_policy_simulations:158 - *** Running 20 simulations.
# 2026-08-05 21:46:48.979 | INFO     | pandemic_control.utils.runners:run_model_policy_simulations:165 - *** Simulations complete. Generating variance plots.
# 2026-08-05 21:47:01.757 | INFO     | pandemic_control.utils.runners:run_model_policy_simulations:184 - *** Simulations completed.
# 280 14560

# %% [markdown]
# # Heatmaps

# %%
import random

from pandemic_control.environment import SEIRADHV_Env
from pandemic_control.utils import (
    Args,
    set_plot_env,
    plot_heatmaps_pop_size,
    plot_heatmaps_ph_pd,
    plot_heatmaps_omega_rho,
)

# %%
args = Args(
    const_policy_simulations=False,
    model_policy_simulations= False,
    plot_heatmaps=True,
    plot_learning_curves=False,
    preprocess_data=False,
    train=False,
    predict=False,

    env_type='SEIRADHV',
    cfg_file='./configs/envs_tests/default-seiradhv.json',
    model_type=None,
    model_weights=None,

    input_dir=None,
    output_dir='./outputs',

    seed=random.choice([33, 45, 75, 99]),
    t_max=365,
    timesteps=728,
    epochs=50,
    rounds=50,
    save_interval=10,
    show_plot=True
    )
set_plot_env()

# %% [markdown]
# ### Deaths, hospitalizations and infections as functions of population size

# %%
plot_heatmaps_pop_size(args)
# Out:
# 2026-08-05 22:17:40.928 | INFO     | pandemic_control.utils.runners:plot_heatmaps_pop_size:195 - *** Plotting deaths, hospitalizations and infections as functions         of population size.
# 2026-08-05 22:17:41.738 | INFO     | pandemic_control.utils.runners:plot_heatmaps_pop_size:264 - *** Done.

# %% [markdown]
# ### Deaths, hospitalizations, infections, cummulative hospitalizations and cummulative infections as functions of population resistance

# %%
plot_heatmaps_ph_pd(args)
# Out:
# 2026-08-05 22:13:59.587 | INFO     | pandemic_control.utils.runners:plot_heatmaps_ph_pd:276 - *** Plotting deaths, hospitalizations, infections, cummulative         hospitalizations and cummulative infections as functions of         population resistance.
# 2026-08-05 22:14:00.877 | INFO     | pandemic_control.utils.runners:plot_heatmaps_ph_pd:401 - *** Done.

# %% [markdown]
# ### Deaths, hospitalizations, infections, vaccinations, cummulative hospitalizations and cummulative infections as functions of vaccination rate/inefficiency

# %%
plot_heatmaps_omega_rho(args)
# Out:
# 2026-08-05 22:14:10.011 | INFO     | pandemic_control.utils.runners:plot_heatmaps_omega_rho:414 - *** Deaths, hospitalizations, infections, vaccinations, cummulative         hospitalizations and cummulative infections as functions of vaccination         rate/inefficiency.
# 2026-08-05 22:14:11.930 | INFO     | pandemic_control.utils.runners:plot_heatmaps_omega_rho:552 - *** Done.

# %% [markdown]
# ######
